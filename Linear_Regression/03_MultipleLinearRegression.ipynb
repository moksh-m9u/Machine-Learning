# %% [markdown]
# # Multiple Linear Regression (2 Features)

# %% [markdown]
# ### Linear Regression for two multiple variables
# For two features:
#
# ŷ = β₀ + β₁x₁ + β₂x₂
#
# - β₀ → intercept
# - β₁, β₂ → coefficients (weights)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np 
import plotly.express as px
import plotly.graph_objects as go

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0  0.757734  0.880111   88.341699
# 1  1.612134  0.650798  112.218643
# 2 -0.759123  1.064390   99.522516
# 3 -0.516225  0.907055   -7.039563
# 4  1.090228 -1.671936 -144.174710

# %%
px.scatter_3d(df, x='feature1', y='feature2', z='target')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 38.26001387495323
# MSE 2315.9763578648153
# R2 score 0.5781008591751688

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)

# 1. Define 'final' first
final = np.vstack((xGrid.ravel().reshape(1,100), yGrid.ravel().reshape(1,100))).T
z_final = lr.predict(final).reshape(10, 10)

z = z_final

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.add_trace(go.Surface(x=x, y=y, z=z))
fig.show()

# %%
lr.coef_
# Out:
# array([44.15193845, 71.53224669])

# %%
lr.intercept_
# Out:
# 14.192391503952468

# %% [markdown]
# ## Key Takeaways
#
# - Linear regression fits a hyperplane (line, plane, etc.)
# - Coefficients quantify feature impact
