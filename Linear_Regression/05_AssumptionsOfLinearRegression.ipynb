# %%
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np 
import seaborn as sns

# %%
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    feature1  feature2  feature3     target
# 0 -0.570563  1.420342  0.495580  -9.763182
# 1 -0.990563  0.556965  1.045064 -24.029355
# 2 -0.674728  0.150617  1.774645  45.616421
# 3  0.388250 -0.387127 -0.110229  34.135737
# 4  1.167882 -0.024104  0.145063  86.663647

# %%
x=df.iloc[:,0:3].values
y=df.iloc[:,-1].values

# %%
x.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.3,random_state=1)

# %%
x_train.shape
# Out:
# (60, 3)

# %%
y_train.shape
# Out:
# (60,)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test[0]
# Out:
# array([-0.83423985,  1.34499246,  0.48624933])

# %%
y_test[4]
# Out:
# 98.69333864552068

# %%
lr.predict(x_test[4:5])
# Out:
# array([112.10917517])

# %%
x_test
# Out:
# array([[-0.83423985,  1.34499246,  0.48624933],
#        [ 0.62747389, -0.05394785,  2.71192633],
#        [ 0.12800782,  1.24161652,  0.08841521],
#        [-0.4129564 ,  1.27727436,  0.25622178],
#        [ 1.86950756,  0.66590511, -0.33750905],
#        [-0.9148222 , -0.89713978, -0.78420535],
#        [-0.41619802,  0.72465766, -0.18907167],
#        [ 1.16788229, -0.02410447,  0.14506321],
#        [-0.38466318,  0.04365869,  0.38033506],
#        [ 0.13801466,  0.93950285,  0.34379452],
#        [ 0.73146574,  0.42596675, -0.7160258 ],
#        [-1.3580452 , -0.06711047, -0.16943686],
#        [ 1.11594518, -0.03030337, -0.31959014],
#        [ 0.69405227, -0.51112899,  1.72941743],
#        [-0.27273554, -2.67652137, -0.04184423],
#        [ 1.6265736 , -1.41987131,  0.35081584],
#        [-1.0259683 , -1.89787143,  0.43175699],
#        [ 2.45758763,  1.06721555, -0.19829026],
#        [-0.15851092, -1.05080794,  1.34407129],
#        [ 0.87428572, -1.29353663,  2.15814934],
#        [ 1.07168393, -1.22090192, -0.86230849],
#        [-0.29403325, -0.68785951,  0.78636292],
#        [-0.34903246, -1.07539011,  1.76768278],
#        [ 0.13349704, -1.28926119, -0.43999131],
#        [-1.11830068,  0.84583341,  1.48754313],
#        [-1.59375081, -0.34914224,  0.17238568],
#        [ 1.86081167,  0.25559049,  0.81560447],
#        [-1.31386475,  0.88462238, -0.47721803],
#        [ 0.00622012, -0.82600396, -0.61025035],
#        [ 1.43069737, -1.04137439,  0.555545  ],
#        [ 1.26408575,  1.89690096,  0.28755765],
#        [ 0.26578705, -0.91209091, -0.57134896],
#        [-0.01862772,  0.48352879,  0.15113037],
#        [ 0.8358439 ,  0.4921189 , -0.14901377],
#        [ 0.9606248 ,  1.68091065, -0.79036569],
#        [-0.47552486, -0.16577702, -0.2413848 ],
#        [-0.84960736, -1.49354967,  1.3999655 ],
#        [ 1.98848968,  1.19505834, -0.78270904],
#        [-1.00523966,  0.59265714,  0.41393413],
#        [ 0.86135761,  0.91900813,  0.32626227],
#        [ 1.70957306,  0.05003364,  0.88131804],
#        [-1.39811601,  0.51679755,  1.49152235],
#        [-1.62246117, -1.23563662, -0.12936101],
#        [-0.7128498 , -1.50891712, -0.25281599],
#        [-0.7129932 ,  0.62524497, -1.02378514],
#        [ 0.28765723, -1.79480704, -2.27224411],
#        [-0.1680901 ,  1.90927681, -0.73746484],
#        [ 1.91082685, -0.45984615, -0.58722031],
#        [-1.32202973, -0.99836688, -1.1390968 ],
#        [ 1.58686654,  1.29787761,  0.85396337],
#        [ 0.1272951 ,  2.19376315, -1.25864659],
#        [-1.4923971 ,  0.28768372,  0.93663257],
#        [ 0.37338994, -0.65725749, -0.04942389],
#        [ 0.23502701, -1.94507226,  0.12730852],
#        [ 1.84790906, -2.21079164, -0.9197196 ],
#        [-0.27460012,  0.43500926,  0.63969236],
#        [ 0.08496406,  1.09777949, -0.43010061],
#        [ 0.09103451,  0.78543225,  0.89714975],
#        [ 0.09071677, -2.21741761, -0.89240633],
#        [ 1.36624284,  1.14726479,  0.76896516],
#        [ 0.88130113,  0.55644294, -0.92429374],
#        [ 1.50089036, -0.87015919, -0.00629878],
#        [ 1.48614836,  0.23671627, -0.2056499 ],
#        [ 0.74363697,  0.13613223,  0.14181052],
#        [-1.47394283,  2.01965064, -0.02878565],
#        [-0.88988898, -1.58094538, -0.42279273],
#        [ 0.24297858,  0.39825763, -1.11441271],
#        [ 0.23140076,  1.19280517, -0.43257638],
#        [ 0.05979049,  0.33223747, -1.10055231],
#        [ 0.31306037, -0.51664792,  0.64506198],
#        [ 1.00253584,  1.1782221 , -0.48900604],
#        [ 2.08964887, -0.73306993,  1.59823525],
#        [-0.42658598, -0.07827675, -1.1692758 ],
#        [ 0.50153968, -0.80669851,  1.44349176],
#        [ 0.13594038,  0.9895728 , -0.81983341],
#        [-2.28179231, -0.32957815, -1.3244887 ],
#        [-0.68959966, -0.35744073, -0.54150372],
#        [-0.15082304,  1.1415331 ,  0.94913384],
#        [-2.03039355, -0.96077511, -0.12284341],
#        [-1.10106763, -1.18504653,  0.98236743],
#        [-0.03494339, -0.14062003, -0.72543348],
#        [ 0.24045678,  0.45303779,  1.61943081],
#        [-1.02493087,  0.89933845,  1.93897846],
#        [-0.58850162, -1.54655582, -0.56037342],
#        [-0.34903539,  0.25282509,  1.99073781],
#        [ 2.07087853,  1.06979836,  0.59358811],
#        [ 1.0128123 , -1.7457235 , -0.83009562],
#        [ 0.56448552,  1.23347104, -0.07974094],
#        [ 1.19218624, -0.45376854,  0.72485682],
#        [-0.53058214, -0.73052664,  0.14898639],
#        [-0.43089006, -0.54027026, -0.64843202],
#        [-0.47589939,  0.29684453, -1.15972295],
#        [-0.8738823 ,  0.02971382, -0.58859438],
#        [-1.00460861, -0.79566757, -0.22404361],
#        [ 0.0084189 , -1.10818335, -0.90828394],
#        [ 0.64316328,  0.24908671,  0.6762164 ],
#        [ 0.25508069, -0.23149741, -0.23963207],
#        [ 0.12224975, -1.15738338,  0.76572107],
#        [ 0.48573721,  0.25789698,  0.48579018],
#        [-0.23733748,  0.88533968,  1.31516722],
#        [ 1.33373782, -0.19741468,  1.04814751],
#        [-0.76883635, -0.23003072, -0.16051336],
#        [ 0.93785693, -0.40986453,  0.68339657],
#        [-1.02387576,  1.12397796, -0.92379202],
#        [-0.67472751,  0.15061687,  1.77464503],
#        [-0.51999175,  0.5587132 ,  0.81481454],
#        [-0.6028851 , -1.91447204, -1.86088953],
#        [ 1.51869216,  0.89635574, -0.61135315],
#        [-2.68510868,  0.01842079,  1.7226692 ],
#        [-0.06436017, -0.99579424,  0.28318592],
#        [-0.57056282,  1.42034231,  0.4955804 ],
#        [-0.5705323 , -2.02907213,  1.96647463],
#        [ 0.27059342,  0.6478298 , -1.02035928],
#        [ 0.69548398,  0.08045739,  0.51309301],
#        [ 1.03895212,  0.63174418, -0.14078644],
#        [ 0.24816803,  0.44578096, -0.12776206],
#        [ 1.63138295, -0.1676986 , -0.64971742],
#        [-1.14372183, -0.36917775, -1.28622933],
#        [-1.48665807,  1.40862696, -0.07121903],
#        [ 0.37086997,  0.86283209, -1.0705855 ],
#        [ 1.10392166,  1.88175499,  0.64142066],
#        [ 1.97611078, -1.24412333,  0.74505627],
#        [-0.02973531, -1.8648058 ,  1.22498574],
#        [-0.88051133,  0.2364056 ,  1.26464491],
#        [ 0.48641448,  0.85151895, -0.68996068],
#        [ 0.66698785,  0.07909219,  2.04633278],
#        [ 0.28266031, -0.04715691, -0.62825081],
#        [-0.80376609, -2.41908317, -0.62641691],
#        [-0.20828342, -0.01497319,  2.3158586 ],
#        [-0.63713486, -0.53957461, -0.40834524],
#        [-1.95576713,  1.81530638,  0.87978795],
#        [-0.29382124,  1.09465308,  0.56195167],
#        [-0.03972984, -0.15651881, -0.85553272],
#        [ 0.76807394, -1.10332826, -0.31680492],
#        [ 1.2622032 ,  1.83136208,  1.05782121],
#        [-0.54535995, -1.54647732, -0.40467741],
#        [-1.63929625,  0.36280349, -1.11278115],
#        [-0.34836832, -1.81101917,  0.74689153],
#        [-1.86565117,  0.07472779,  0.90452849],
#        [ 0.82653585,  1.06930572, -0.6519202 ]])

# %%
# Residual
y_pred = lr.predict(x_test)
residual = y_test - y_pred
