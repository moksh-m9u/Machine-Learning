# %%
import numpy as np
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
x
# Out:
# array([[-0.71239066],
#        [ 0.45181234],
#        [-0.04450308],
#        [ 0.75376638]])

# %%
y
# Out:
# array([  7.21786552,  16.04609925, -27.83756166, 144.36688189])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([78.35063668])

# %%
lr.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red')

# %%
#y_pred=((78.35*x)+0).reshape(4)
y_pred=((78.35*x)+100)

# %%
y_pred.shape
# Out:
# (4, 1)

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')
plt.plot(x,y_pred,color='green',label='b=0')
plt.legend()

# %%
m=78.35
b=100

# %%
loss_slope=-2*np.sum(y-m*x.ravel()-b)

# %%
loss_slope
# Out:
# 590.7223659179078

# %%
learning_rate=0.1
StepSize=learning_rate*loss_slope
StepSize
# Out:
# 59.072236591790784

# %%
#new intercept
b=b-StepSize
b
# Out:
# 40.927763408209216

# %%
y_pred1=((78.35*x)+b)

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')
plt.plot(x,y_pred,color='green',label='b=0')
plt.plot(x,y_pred1,color='pink',label='b=0')
plt.legend()

# %%
loss_slope=-2*np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# 118.14447318358157

# %%
StepSize=learning_rate*loss_slope
StepSize
# Out:
# 11.814447318358157

# %%
b=b-StepSize
b
# Out:
# 29.11331608985106

# %%
y_pred2=m*x.ravel() + b

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')
plt.plot(x,y_pred,color='green',label='b=0')
plt.plot(x,y_pred1,color='pink',label='1st iteration')
plt.plot(x,y_pred2,color='yellow',label='2nd iteration')
plt.legend()

# %%
loss_slope=-2*np.sum(y-m*x.ravel()-b)
loss_slope
# Out:
# 23.62889463671634

# %%
StepSize=loss_slope*learning_rate
StepSize
# Out:
# 2.362889463671634

# %%
b=b-StepSize
b
# Out:
# 26.750426626179426

# %%
y_pred3=m*x.ravel()+b

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red',label='ols')
plt.plot(x,y_pred,color='green',label='b=0')
plt.plot(x,y_pred1,color='pink',label='1st iteration')
plt.plot(x,y_pred2,color='yellow',label='2nd iteration')
plt.plot(x,y_pred3,color='purple',label='3rd iteration')
plt.legend()

# %%
b = -100
m = 78.35
lr = 0.01

epochs = 100

for i in range(epochs):
  loss_slope = -2 * np.sum(y - m*x.ravel() - b)
  b = b - (lr * loss_slope)

  y_pred = m * x + b

  plt.plot(x,y_pred)

plt.scatter(x,y)
b
# Out:
# 26.129525360899255
